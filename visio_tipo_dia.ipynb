# %% [markdown]
# #### Docks disponiles los días laborables
#
# En la siguiente reproducción se muestra el promedio de docks disponibles en cada estación en función de la siguiente franja horaria:
#
# 1. *primera hora mañana*: de 3 a 6
# 2. *mañana*: de 7 a 11
# 3. *medio día*: de 12 a 15
# 4. *primera hora tarde*: de 16 a 19
# 5. *tarde*: de 20 a 23
# 6. *noche*: de 0 a 2
#
# Escala de color: de morado a azul corresponde a de 0 a 1 en ratio doncs disponibles. El tamaño igual

# %%
from IPython.display import Video

# Ruta al archivo MP4
ruta_archivo = 'C:/Users/gerar/Documents/Postgrau DSML/Capstone project/BicingBCN/Maps/Feb_laborables/Febrero laborables.mp4'
# https://github.com/jotogi/BicingBCN/blob/main/Febrero%20laborables.mp4

# Crear el widget de video
Video(ruta_archivo, embed=True, width=800, height=600)
# Out:
# <video controls  width="800"  height="600">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# Se puede observar como en las primeras horas del día (3h-6h) las estaciones de las zonas de Gràcia, Sagrada Família y Sant Antoni, Poble Sec, Sants es donde se encuentran las estaciones más llenas. <br>
# En la siguiente franja horaria, de 7h-11h, se nota el movimiento: en esas zonas las estaciones de vacían (docks disponibles aumentan). Y las estaciones de l'Eixample se llenan, igual que las de la zona alta de la Diagonal y Poblenou. <br>
# No es hasta primera hora de la tarde (16h-19h) que se vuelve a apreciar otro cambio de comportamiento. Durante estas horas se puede observar como la ciudad queda dividida en dos: la zona alta donde las estaciones tienen un % de docks disponibles alto, y la zona baja (playa) donde ocurre lo contratio.<br>
# En las dos siguientes franjas del día (de 20h-23h y 00h-2h) la disponiblidad de docks se va reordenando volviendo al punto inicial.
#
# #### Docks disponiles los fines de semana
#
# En el siguiente video se visualiza los mismo para los fines de semana:

# %%
# https://github.com/jotogi/BicingBCN/blob/main/Febrero%20findes.mp4

ruta_archivo = 'C:/Users/gerar/Documents/Postgrau DSML/Capstone project/BicingBCN/Maps/Feb_finde/Febrero findes.mp4'
Video(ruta_archivo, embed=True, width=800, height=600)
# Out:
# <video controls  width="800"  height="600">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# El punto de partida parece ser muy similar al de los días entre semana: las primeras horas del día (3h-6h) las estaciones de las zonas de Gràcia, Sagrada Família y Sant Antoni, Poble Sec, Sants es donde se encuentran las estaciones más llenas. <br>
# Sin embargo, en la franja franja horaria de 7h-11h las zonas de Poblenou y parte alta de la Diagonal ya no se llenan.
#
# #### Diferencias de disponibilidad de los días entre semana vs los fines de semana
#
# Se calcula la diferencia para cada estación y franja horaria entre el % de docks disponible entre semana menos el % del fin de semana. Por lo tanto, valores positivos indican mayor disponiblidad de docks entre semama (color verde en los mapas) y los negativos (en amarillo) mayor disponiblidad el fin de semana. El tamaño de los puntos también va en función de la disponibilidad.<br><br>
# Lo vemos en la siguiente infografía:

# %%
import matplotlib.pyplot as plt
from PIL import Image

# Ruta de la imagen PNG
ruta_imagen = 'C:/Users/gerar/Documents/Postgrau DSML/Capstone project/BicingBCN/Maps/diff findes/dif_franj.png'

# Cargar la imagen
imagen = Image.open(ruta_imagen)

plt.figure(figsize=(12, 12))

# Mostrar la imagen en el notebook
plt.imshow(imagen)
plt.axis('off')
plt.show()

# %% [markdown]
# Distinguimos dos situaciones en función de la fanja horaria:
#
# 1. Se obsevan diferencias de en distintos puntos de la ciudad
# 2. **Las diferencias nos permiten prácticamente trazar fronteras muy claras**. Vamos a fijarnos en esto.
#
# De 7h-10h se observa una zona amarilla que cruza la ciudad. En esta zona, durante el fin de semana y a esta hora, hay menos docks vacíos. Y a medida que pasa el día, de 20-23h el comportamientos cambia: esta zona que antes era amarilla, se vuelve verde indicando que en este momento hay más docks ocupados.
